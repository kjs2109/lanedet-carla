# %%
import os 
import cv2 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
image_root = '/root/works/lanedet/demo/images'
demo_images = os.listdir(image_root) 

carla_image_paths = [os.path.join(image_root, image) for image in demo_images if 'carla' in image] 
culane_image_paths = [os.path.join(image_root, image) for image in demo_images if 'culane' in image] 
tusimple_image_paths = [os.path.join(image_root, image) for image in demo_images if 'tusimple' in image] 
campus_image_paths = [os.path.join(image_root, image) for image in demo_images if 'campus' in image] 
dss_image_paths = [os.path.join(image_root, image) for image in demo_images if 'dss' in image]

# %%
carla_img = cv2.imread(carla_image_paths[0]) 
carla_img = cv2.cvtColor(carla_img, cv2.COLOR_BGR2RGB) 

print(carla_img.shape)
print(carla_img.dtype) 
print(type(carla_img)) 
print(carla_img.max()) 
print(carla_img.min()) 
plt.imshow(carla_img)
plt.show()
# Out:
# (600, 800, 3)
# uint8
# <class 'numpy.ndarray'>
# 251
# 0

# %%
from tools.my_detect import Detect 
from lanedet.utils.config import Config

# carla config 
config_file = '/root/works/lanedet/demo/configs/carla_scnn_tusimple.py'

cfg = Config.fromfile(config_file)
cfg.show = False 
cfg.savedir = '/root/works/lanedet'
cfg.load_from = '/root/works/lanedet/demo/checkpoints/scnn_r18_tusimple.pth'
carla_detect = Detect(cfg)

# %%
result_img = carla_detect.vis_inference(carla_img, cfg) 
plt.imshow(result_img)

# %%
data_dict = {'img_path': 'a', 'img_name': 'b'}

sample = data_dict.copy() 
sample
# Out:
# {'img_path': 'a', 'img_name': 'b'}

# %%
import numpy as np 
sample.update({'img': np.zeros((1, 1, 3))}) 
sample
# Out:
# {'img_path': 'a', 'img_name': 'b', 'img': array([[[0., 0., 0.]]])}

# %%
sample.keys()
# Out:
# dict_keys(['img_path', 'img_name', 'img'])

# %%
dict1 = {'a': 1, 'b': 2} 
dict2 = {'c': 3, 'd': 4} 

li = [] 

li.append(dict1) 
li.append(dict2) 

li
# Out:
# [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]

# %%
data = [[{'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001909.png', 'img_name': '000000001909.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001910.png', 'img_name': '000000001910.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001933.png', 'img_name': '000000001933.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001915.png', 'img_name': '000000001915.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001936.png', 'img_name': '000000001936.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001929.png', 'img_name': '000000001929.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001940.png', 'img_name': '000000001940.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001907.png', 'img_name': '000000001907.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001926.png', 'img_name': '000000001926.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001923.png', 'img_name': '000000001923.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001932.png', 'img_name': '000000001932.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001951.png', 'img_name': '000000001951.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001946.png', 'img_name': '000000001946.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001938.png', 'img_name': '000000001938.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001921.png', 'img_name': '000000001921.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001902.png', 'img_name': '000000001902.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001913.png', 'img_name': '000000001913.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001920.png', 'img_name': '000000001920.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001924.png', 'img_name': '000000001924.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001912.png', 'img_name': '000000001912.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001906.png', 'img_name': '000000001906.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001916.png', 'img_name': '000000001916.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001908.png', 'img_name': '000000001908.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001922.png', 'img_name': '000000001922.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001919.png', 'img_name': '000000001919.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001945.png', 'img_name': '000000001945.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001934.png', 'img_name': '000000001934.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001931.png', 'img_name': '000000001931.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001949.png', 'img_name': '000000001949.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001925.png', 'img_name': '000000001925.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001928.png', 'img_name': '000000001928.png'}, {'full_img_path': '/root/works/lanedet/data/DSS/images/scenario_9/000000001939.png', 'img_name': '000000001939.png'}]]

# %%
len(data)
# Out:
# 1

# %%
len(data[0])
# Out:
# 32

# %%
data[0][0].keys()
# Out:
# dict_keys(['full_img_path', 'img_name'])

# %%
import cv2 
import matplotlib.pyplot as plt 
from PIL import Image 
import numpy as np 

gt_mask = Image.open('/root/works/lanedet/gt_mask_0.png') 
gt_mask_array = np.array(gt_mask) 

gt_mask.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=640x368>

# %%
plt.imshow(np.array(gt_mask), cmap='gray')

# %%
cv_gt_mask = cv2.imread('/root/works/lanedet/data/DSS/seg_labels/scenario_2/000000002329.png', cv2.IMREAD_UNCHANGED) 
cv_gt_mask = cv_gt_mask[:, :, 0] 
cv_gt_mask = cv_gt_mask.squeeze() 

cv_gt_mask = cv2.resize(cv_gt_mask, (640, 368), interpolation=cv2.INTER_NEAREST)

print(cv_gt_mask.shape) 
plt.imshow(cv_gt_mask, cmap='gray')
# Out:
# (368, 640)

# %%
cv_gt_mask.squeeze().shape
# Out:
# (368, 640)

# %%
pil_gt_mask = Image.fromarray(gt_mask, mode='L') 
pil_gt_mask.show()
# Out:
# <PIL.Image.Image image mode=L size=640x368>

# %%
gt_mask_array.shape
# Out:
# (368, 640)

# %%
print(gt_mask_array.min()) 
print(gt_mask_array.max())
# Out:
# 0
# 1

# %%
gt_mask = cv2.imread('/root/works/lanedet/gt_mask_0.png', cv2.IMREAD_UNCHANGED) 
pred_mask1 = cv2.imread('/root/works/lanedet/pred_mask1_0.png', cv2.IMREAD_UNCHANGED) 
pred_mask2 = cv2.imread('/root/works/lanedet/pred_mask2_0.png', cv2.IMREAD_UNCHANGED) 

print(gt_mask.shape) 
print(pred_mask1.shape) 
print(pred_mask2.min()) 
print(pred_mask2.max()) 

# plot 1x3 images using matplotlib 
plt.figure(figsize=(12, 4)) 
plt.subplot(131)
plt.imshow(gt_mask, cmap='gray')
plt.subplot(132)
plt.imshow(pred_mask1, cmap='gray')
plt.subplot(133)
plt.imshow(pred_mask2, cmap='gray') 

plt.show()
# Out:
# (368, 640)
# (368, 640)
# 0
# 255

# %%
import math 
import torch 

def calc_dice(im1, im2): 
    if torch.is_tensor(im1): 
        im1 = im1.cpu().numpy() 
    if torch.is_tensor(im2): 
        im2 = im2.cpu().numpy() 

    im1 = np.asarray(im1).astype(np.bool_) 
    im2 = np.asarray(im2).astype(np.bool_) 

    if im1.shape != im2.shape: 
        raise ValueError("Shape mismatch: im1 and im2 must have the same shape.") 
    
    intersection = np.logical_and(im1, im2) 
    dice_score = 2. * intersection.sum() / (im1.sum() + im2.sum()) 

    return dice_score if not math.isnan(dice_score) else 0.0

# %%
calc_dice(gt_mask, pred_mask1)
# Out:
# 0.02031161509276489

# %%
calc_dice(gt_mask, pred_mask2)
# Out:
# 0.7927673318721883
